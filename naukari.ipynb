# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
pd.read_csv("naukri_data_science_jobs_india.csv")
# Out:
#                                                 Job_Role  \
# 0                                  Senior Data Scientist
# 1                                  Senior Data Scientist
# 2      Applied Data Scientist / ML Senior Engineer (P...
# 3                                         Data Scientist
# 4                                         Data Scientist
# ...                                                  ...
# 11995                Tech Lead/Architect ( Contractual )
# 11996                               Tech Lead / POD Lead
# 11997     Java Full Stack Developer - Hibernate / Spring
# 11998                                  Tech Lead - Azure
# 11999            Full Stack Developer - Machine Learning
#
#                                   Company  \
# 0                                     UPL
# 1                                 Walmart
# 2                       SAP India Pvt.Ltd
# 3                                     UPL
# 4                                 Walmart
# ...

# %%
df=pd.read_csv("naukri_data_science_jobs_india.csv")

# %%
df.isnull().sum()
# Out:
# Job_Role              0
# Company               0
# Location              0
# Job Experience        0
# Skills/Description    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Job_Role            12000 non-null  object
#  1   Company             12000 non-null  object
#  2   Location            12000 non-null  object
#  3   Job Experience      12000 non-null  object
#  4   Skills/Description  12000 non-null  object
# dtypes: object(5)
# memory usage: 468.9+ KB

# %%
df["Location"].value_counts().head(10)
# Out:
# Location
# Bangalore/Bengaluru       3383
# Pune                      1179
# Hyderabad/Secunderabad     963
# Mumbai                     816
# Gurgaon/Gurugram           698
# Chennai                    660
# Bengaluru                  342
# Noida                      290
# Remote                     153
# Hyderabad                  137
# Name: count, dtype: int64

# %%
list(df.columns)
# Out:
# ['Job_Role', 'Company', 'Location', 'Job Experience', 'Skills/Description']

# %%
df['Company'].value_counts().head(10)
# Out:
# Company
# Accenture                          490
# IBM                                316
# Infostretch solutions Pvt. Ltd.    304
# Huquo Consulting Pvt. Ltd          295
# Anicalls                           115
# BNY Mellon                         103
# Microsoft                           92
# Deutsche Bank                       84
# Career Infosystem                   82
# Serving Skill                       76
# Name: count, dtype: int64

# %%
skills_series =df['Skills/Description'].dropna().str.lower().str.split().explode().str.strip()

# %%
top_skills = skills_series.value_counts().head(20)
top_skills_df = top_skills.reset_index()
top_skills_df.columns = ['Skill', 'Count']
print(top_skills_df)
# Out:
#           Skill  Count
# 0          data  11993
# 1       skills,   3235
# 2   management,   3228
# 3            it   3076
# 4       python,   2753
# 5      science,   2494
# 6     analysis,   2427
# 7      business   2248
# 8       machine   1824
# 9     learning,   1796
# 10   analytics,   1690
# 11          big   1636
# 12     computer   1458
# 13        data,   1408
# 14         sql,   1367
# 15     analyst,   1267
# 16        java,   1249
# 17  analytical,   1246
# 18       cloud,   1226
# 19          sql   1127

# %%
df['Job_Role'].value_counts().head(10)
# Out:
# Job_Role
# Data Engineer                            580
# Data Scientist                           505
# Data Analyst                             353
# Senior Technical Lead (Data Engineer)    276
# Senior Data Engineer                     197
# Business Analyst                         197
# Senior Data Scientist                     97
# Azure Data Engineer                       80
# Data Engineer: Data Integration           75
# Big Data Engineer                         71
# Name: count, dtype: int64

# %%
# Count jobs per location (top 10)
location_counts = df["Location"].value_counts().head(10)

# Bar plot
plt.figure(figsize=(10, 6))
location_counts.plot(kind='barh', color='lightgreen')
plt.title("Top 10 Locations by Job Count")
plt.xlabel("Number of Jobs")
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %%
# Count jobs per company (top 10)
company_counts = df["Company"].value_counts().head(10)

# Bar plot
plt.figure(figsize=(10, 6))
company_counts.plot(kind='barh', color='orange')
plt.title("Top 10 Hiring Companies")
plt.xlabel("Number of Jobs")
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %%
# Count jobs per role (top 10)
role_counts = df["Job_Role"].value_counts().head(10)

# Bar plot
plt.figure(figsize=(10, 6))
role_counts.plot(kind='barh', color='purple')
plt.title("Top 10 Job Roles")
plt.xlabel("Number of Jobs")
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()
